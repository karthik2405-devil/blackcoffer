# %% [markdown]
# <a href="https://colab.research.google.com/github/karthik2405-devil/blackcoffer/blob/main/NLP_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.read_csv("/content/Input.csv")
df
# Out:
#      URL_ID                                                URL
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
# [114 rows x 2 columns]

# %%
import requests
from bs4 import BeautifulSoup

def extract_text(url):
  
    headers = {
      "User-Agent": "Mozilla/5.0 (X11; Linux x86_64; rv:60.0) Gecko/20100101 Firefox/60.0"
    } 
    # make a GET request to the webpage
    response = requests.get(url,headers=headers)
    #print(response.content)
    #parse the response HTML using Beautiful Soup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # extract the title and article text
    title = soup.title.string
   # print(title)
    article=soup.find('article')
    article_text = article.find('div', class_='td-post-content').get_text()
    #print(article_text)
    ans = analyse(article_text)
    return ans
    #print(article_text)
    # save the extracted text to a file with the URL_ID as its filename
    #print(article_text)

# %%
# !pip install textstat
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download("punkt")
nltk.download('vader_lexicon')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# import transformers
import nltk
import textstat
from nltk.sentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
from nltk.corpus import brown
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize, word_tokenize

# Load the BERT model and tokenizer
# model = transformers.BertModel.from_pretrained('bert-base-uncased')
# tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-uncased')
def analyse(text):
  # Tokenize the input text
  # input_ids = tokenizer.encode_plus(text, return_tensors='pt', truncation=True, return_attention_mask=True)
  # Generate the attention mask

  # attention_mask = input_ids["attention_mask"][0]
  # input_ids = input_ids["input_ids"][0]
  sia = SentimentIntensityAnalyzer()
  # Perform sentiment analysis
  # output = model(**input_ids)
  # Get the sentiment score from the output
  # sentiment_score = output[0][:,0]
  score = sia.polarity_scores(text)

# Get the positive score
  positive_score = score["pos"]

  #get the polarity and subjective score from the output
  
  
  #polar = sia.polarity_scores(text)

  blob = TextBlob(text)
  subjectivity = blob.sentiment.subjectivity
  polarity = blob.sentiment.polarity
  #Calculate percentage complex words
  words = word_tokenize(text)

    # Get the number of complex words
  fdist = nltk.FreqDist(w.lower() for w in words if w.isalpha() and nltk.corpus.wordnet.synsets(w))
  num_complex_words = sum(fdist.values())

    # Get the total number of words
  num_words = len(words)

    # Calculate the percentage of complex words
  percentage_complex_words = (num_complex_words / num_words) * 100
  # Calculate other text attributes
  tokens = nltk.word_tokenize(text)
  avg_sentence_length = textstat.avg_sentence_length(text)
  
  fog_index = textstat.gunning_fog(text)

  #calculate avg_words_per_sentence
  sentences = nltk.sent_tokenize(text)
  word_count = sum([len(word_tokenize(sentence)) for sentence in sentences])
    # Get the total number of sentences
  sentence_count = len(sentences)
    # calculate the average words per sentence
  average = word_count/sentence_count

  #calculate complex word count 
  

# Get the number of complex words
  complex_words = [word for word in words if nltk.corpus.wordnet.synsets(word)]
  num_complex_words = len(complex_words)
  

  #
  word_count = len(tokens)
  syllables_per_word = textstat.syllable_count(text) / len(tokens)


  #calculate personal_pronoun
  personal_pronouns = ['I','me','you','he','him','she','her','it','we','us','they','them']
  num_personal_pronouns = sum(word.lower() in personal_pronouns for word in words)

  #calculate avg word length
  char_count = sum(len(word) for word in words)
  word_count = len(words)
  avg_word_length = char_count/word_count
  
  
  # Return the results
  return {
      #'positive_score': sentiment_score,
      'positive_score': score["pos"],
      #'negative_score': 1 - sentiment_score,
      'negative_score': score["neg"],
      #'polarity_score': polar,
      'polarity_score':polarity,
      'subjectivity_score': subjectivity,
      'avg_sentence_length': avg_sentence_length,
      'percentage_complex_words': percentage_complex_words,
      'fog_index': fog_index,
      'avg_words_per_sentence': average,
      'complex_word_count': num_complex_words,
      'word_count': word_count,
      'syllables_per_word': syllables_per_word,
      'personal_pronouns': num_personal_pronouns,
      'avg_word_length': avg_word_length
  }

# %%
ans = extract_text("https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/")
print(ans)
# Out:
# {'positive_score': 0.145, 'negative_score': 0.044, 'polarity_score': 0.13693643937761585, 'subjectivity_score': 0.46336424033482865, 'avg_sentence_length': 22.4, 'percentage_complex_words': 68.24055666003976, 'fog_index': 14.57, 'avg_words_per_sentence': 26.12987012987013, 'complex_word_count': 1381, 'word_count': 2012, 'syllables_per_word': 1.5795228628230615, 'personal_pronouns': 22, 'avg_word_length': 5.1600397614314115}

# %%
data=pd.read_csv("/content/Output.csv")
data.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...             NaN
# 1      38  https://insights.blackcoffer.com/what-if-the-c...             NaN
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...             NaN
# 3      40  https://insights.blackcoffer.com/will-machine-...             NaN
# 4      41  https://insights.blackcoffer.com/will-ai-repla...             NaN
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0             NaN             NaN                 NaN                  NaN
# 1             NaN             NaN                 NaN                  NaN
# 2             NaN             NaN                 NaN                  NaN
# 3             NaN             NaN                 NaN                  NaN
# 4             NaN             NaN                 NaN                  NaN
#
# ...

# %%
for i in range(len(df)):
  url = df.iloc[i, 1]
  try: 
    ans=extract_text(url)    
    for key, val in ans.items():
      df.loc[i, key] = val
  except:
    pass

# %%
df.isna().sum()
# Out:
# URL_ID                      0
# URL                         0
# positive_score              3
# negative_score              3
# polarity_score              3
# subjectivity_score          3
# avg_sentence_length         3
# percentage_complex_words    3
# fog_index                   3
# avg_words_per_sentence      3
# complex_word_count          3
# word_count                  3
# syllables_per_word          3
# personal_pronouns           3
# avg_word_length             3
# dtype: int64

# %%
df.loc[df.isna().any(axis=1)]
# Out:
#      URL_ID                                                URL  \
# 7        44  https://insights.blackcoffer.com/how-neural-ne...
# 20       57  https://insights.blackcoffer.com/covid-19-envi...
# 107     144  https://insights.blackcoffer.com/ensuring-grow...
#
#      positive_score  negative_score  polarity_score  subjectivity_score  \
# 7               NaN             NaN             NaN                 NaN
# 20              NaN             NaN             NaN                 NaN
# 107             NaN             NaN             NaN                 NaN
#
#      avg_sentence_length  percentage_complex_words  fog_index  \
# 7                    NaN                       NaN        NaN
# 20                   NaN                       NaN        NaN
# 107                  NaN                       NaN        NaN
#
#      avg_words_per_sentence  complex_word_count  word_count  \
# 7                       NaN                 NaN         NaN
# ...

# %%
df.to_csv("final_output.csv")
